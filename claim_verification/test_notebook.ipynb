# %%
# All important imports
import os
import json

from dotenv import load_dotenv
from pypdf import PdfReader
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from pydantic.v1 import BaseModel, Field

# %%
# Load the environment
load_dotenv()
os.environ["OPEN_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %%
# Read the PDF
reader = PdfReader('sf_data_with_attachments/pitchdeck_0624_pay33.pdf')
content = ""

for page in reader.pages:
    content += page.extract_text()
# Out:
# Ignoring wrong pointing object 9 0 (offset 0)
# Ignoring wrong pointing object 26 0 (offset 0)
# Ignoring wrong pointing object 53 0 (offset 0)
# Ignoring wrong pointing object 55 0 (offset 0)
# Ignoring wrong pointing object 58 0 (offset 0)
# Ignoring wrong pointing object 60 0 (offset 0)
# Ignoring wrong pointing object 63 0 (offset 0)
# Ignoring wrong pointing object 65 0 (offset 0)
# Ignoring wrong pointing object 86 0 (offset 0)
# Ignoring wrong pointing object 88 0 (offset 0)
# Ignoring wrong pointing object 90 0 (offset 0)
# Ignoring wrong pointing object 112 0 (offset 0)
# Ignoring wrong pointing object 114 0 (offset 0)
# Ignoring wrong pointing object 116 0 (offset 0)
# Ignoring wrong pointing object 127 0 (offset 0)
# Ignoring wrong pointing object 131 0 (offset 0)
# Ignoring wrong pointing object 135 0 (offset 0)
# Ignoring wrong pointing object 160 0 (offset 0)
# Ignoring wrong pointing object 162 0 (offset 0)
# Ignoring wrong pointing object 164 0 (offset 0)
# Ignoring wrong pointing object 166 0 (offset 0)
# Ignoring wrong pointing object 168 0 (offset 0)
# Ignoring wrong pointing object 170 0 (offset 0)
# Ignoring wrong pointing object 172 0 (offset 0)
# Ignoring wrong pointing object 174 0 (offset 0)
# Ignoring wrong pointing object 176 0 (offset 0)
# Ignoring wrong pointing object 178 0 (offset 0)
# Ignoring wrong pointing object 180 0 (offset 0)
# Ignoring wrong pointing object 182 0 (offset 0)
# Ignoring wrong pointing object 184 0 (offset 0)
# Ignoring wrong pointing object 186 0 (offset 0)
# Ignoring wrong pointing object 188 0 (offset 0)
# Ignoring wrong pointing object 190 0 (offset 0)
# Ignoring wrong pointing object 192 0 (offset 0)
# Ignoring wrong pointing object 194 0 (offset 0)
# Ignoring wrong pointing object 196 0 (offset 0)
# Ignoring wrong pointing object 198 0 (offset 0)
# Ignoring wrong pointing object 200 0 (offset 0)
# Ignoring wrong pointing object 202 0 (offset 0)
# Ignoring wrong pointing object 314 0 (offset 0)
# Ignoring wrong pointing object 316 0 (offset 0)
# Ignoring wrong pointing object 318 0 (offset 0)
# Ignoring wrong pointing object 320 0 (offset 0)
# Ignoring wrong pointing object 322 0 (offset 0)
# Ignoring wrong pointing object 324 0 (offset 0)
# Ignoring wrong pointing object 326 0 (offset 0)
# Ignoring wrong pointing object 328 0 (offset 0)
# Ignoring wrong pointing object 330 0 (offset 0)
# Ignoring wrong pointing object 332 0 (offset 0)
# Ignoring wrong pointing object 334 0 (offset 0)
# Ignoring wrong pointing object 336 0 (offset 0)
# Ignoring wrong pointing object 365 0 (offset 0)
# Ignoring wrong pointing object 367 0 (offset 0)
# Ignoring wrong pointing object 369 0 (offset 0)
# Ignoring wrong pointing object 371 0 (offset 0)
# Ignoring wrong pointing object 373 0 (offset 0)
# Ignoring wrong pointing object 375 0 (offset 0)
# Ignoring wrong pointing object 406 0 (offset 0)
# Ignoring wrong pointing object 408 0 (offset 0)
# Ignoring wrong pointing object 410 0 (offset 0)
# Ignoring wrong pointing object 412 0 (offset 0)
# Ignoring wrong pointing object 414 0 (offset 0)
# Ignoring wrong pointing object 429 0 (offset 0)
# Ignoring wrong pointing object 431 0 (offset 0)
# Ignoring wrong pointing object 433 0 (offset 0)
# Ignoring wrong pointing object 442 0 (offset 0)
# Ignoring wrong pointing object 444 0 (offset 0)
# Ignoring wrong pointing object 446 0 (offset 0)
# Ignoring wrong pointing object 448 0 (offset 0)
# Ignoring wrong pointing object 450 0 (offset 0)
# Ignoring wrong pointing object 452 0 (offset 0)
# Ignoring wrong pointing object 454 0 (offset 0)
# Ignoring wrong pointing object 456 0 (offset 0)
# Ignoring wrong pointing object 458 0 (offset 0)
# Ignoring wrong pointing object 500 0 (offset 0)
# Ignoring wrong pointing object 502 0 (offset 0)
# Ignoring wrong pointing object 504 0 (offset 0)
# Ignoring wrong pointing object 515 0 (offset 0)
# Ignoring wrong pointing object 517 0 (offset 0)
# Ignoring wrong pointing object 519 0 (offset 0)
# Ignoring wrong pointing object 521 0 (offset 0)
# Ignoring wrong pointing object 523 0 (offset 0)
# Ignoring wrong pointing object 525 0 (offset 0)
# Ignoring wrong pointing object 527 0 (offset 0)
# Ignoring wrong pointing object 680 0 (offset 0)
# Ignoring wrong pointing object 682 0 (offset 0)
# Ignoring wrong pointing object 684 0 (offset 0)
# Ignoring wrong pointing object 686 0 (offset 0)
# Ignoring wrong pointing object 688 0 (offset 0)
# Ignoring wrong pointing object 690 0 (offset 0)
# Ignoring wrong pointing object 692 0 (offset 0)
# Ignoring wrong pointing object 712 0 (offset 0)
# Ignoring wrong pointing object 714 0 (offset 0)
# Ignoring wrong pointing object 716 0 (offset 0)
# Ignoring wrong pointing object 718 0 (offset 0)
# Ignoring wrong pointing object 720 0 (offset 0)
# Ignoring wrong pointing object 722 0 (offset 0)
# Ignoring wrong pointing object 740 0 (offset 0)
# Ignoring wrong pointing object 742 0 (offset 0)
# Ignoring wrong pointing object 745 0 (offset 0)
# Ignoring wrong pointing object 747 0 (offset 0)
# Ignoring wrong pointing object 749 0 (offset 0)
# Ignoring wrong pointing object 751 0 (offset 0)
# Ignoring wrong pointing object 755 0 (offset 0)
# Ignoring wrong pointing object 757 0 (offset 0)
# Ignoring wrong pointing object 822 0 (offset 0)
# Ignoring wrong pointing object 824 0 (offset 0)
# Ignoring wrong pointing object 826 0 (offset 0)
# Ignoring wrong pointing object 828 0 (offset 0)
# Ignoring wrong pointing object 830 0 (offset 0)
# Ignoring wrong pointing object 832 0 (offset 0)
# Ignoring wrong pointing object 834 0 (offset 0)
# Ignoring wrong pointing object 836 0 (offset 0)
# Ignoring wrong pointing object 857 0 (offset 0)
# Ignoring wrong pointing object 859 0 (offset 0)
# Ignoring wrong pointing object 861 0 (offset 0)
# Ignoring wrong pointing object 863 0 (offset 0)
# Ignoring wrong pointing object 865 0 (offset 0)
# Ignoring wrong pointing object 867 0 (offset 0)
# Ignoring wrong pointing object 869 0 (offset 0)
# Ignoring wrong pointing object 871 0 (offset 0)
# Ignoring wrong pointing object 873 0 (offset 0)
# Ignoring wrong pointing object 876 0 (offset 0)
# Ignoring wrong pointing object 878 0 (offset 0)
# Ignoring wrong pointing object 880 0 (offset 0)
# Ignoring wrong pointing object 882 0 (offset 0)
# Ignoring wrong pointing object 924 0 (offset 0)
# Ignoring wrong pointing object 926 0 (offset 0)
# Ignoring wrong pointing object 928 0 (offset 0)
# Ignoring wrong pointing object 930 0 (offset 0)
# Ignoring wrong pointing object 944 0 (offset 0)
# Ignoring wrong pointing object 946 0 (offset 0)
# Ignoring wrong pointing object 968 0 (offset 0)
# Ignoring wrong pointing object 970 0 (offset 0)

# %%
# Define structure of the extracted claims
class Claim(BaseModel):
    number: int = Field(description="The number of the claim")
    description: str = Field(description="Description of the name")
    verifiable: bool = Field(description="Indicator whether the claim can be verified")
    
class ClaimList(BaseModel):
    claims: list[Claim] = Field(description="Claims extracted from the file")

# %%
# Extract claims

model = ChatOpenAI(model="gpt-4o", temperature=0)

structured_llm = model.with_structured_output(ClaimList)

prompt = ChatPromptTemplate.from_messages([
    ("system", "Extract the claims from the provided text"),
    ("human", "{user_request}")
])

chain = prompt | structured_llm

response = chain.invoke({
    "user_request": content
})

print("--- Response Object ---")
print(response)

print("\n--- Type of Response ---")
print(type(response))
# Out:
# /opt/anaconda3/envs/nlp/lib/python3.11/site-packages/langchain_openai/chat_models/base.py:1950: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# --- Response Object ---
# claims=[Claim(number=1, description='90% of public charging points for Germany’s 2030 target remain to be built.', verifiable=True), Claim(number=2, description='40 million electric vehicles are expected by 2030 based on emissions regulation and incentives, which is 30 million more than in 2024.', verifiable=True), Claim(number=3, description='80% of companies with more than 20 parking spaces must install electric chargers.', verifiable=True), Claim(number=4, description='45% of companies see complexity in billing/payments as the main challenge for e-mobility.', verifiable=True), Claim(number=5, description='Europe’s first B2B2C white-label solution unifying mobility, payment, and loyalty is offered by pay33.', verifiable=False), Claim(number=6, description='Pay33 provides access to more than 650,000 EU charging points.', verifiable=True), Claim(number=7, description='Pay33 offers a white-label banking solution that opens local IBAN accounts for users in 19 EU countries.', verifiable=True), Claim(number=8, description="Pay33's business model includes revenue scaling through subscriptions and transactions.", verifiable=True), Claim(number=9, description='Pay33 is the only integrated mobility, payment, and loyalty solution in Europe.', verifiable=False), Claim(number=10, description='The total addressable market for pay33 is 385 billion euros, with a serviceable obtainable market of 2 billion euros.', verifiable=True), Claim(number=11, description='Pay33 plans to use a 1.0 million euro seed round for product enhancements, personnel, and company development.', verifiable=True)]
#
# --- Type of Response ---
# <class '__main__.ClaimList'>

# %%
# Define structure of the claim verification result
class VerificationResult(BaseModel):
    claim: Claim = Field(description="Claim")
    valid: bool = Field(description="Indicator whether the claim is valid")
    reasoning: str = Field(description="Explanation why the calim is true/false")
    sources: list[str] = Field(description="List of the URL sources used to support the reasoning")
    
class VerificationList(BaseModel):
    verification_results: list[VerificationResult] = Field(description="List of the verification results")

# %%
# Filter the claims
response.claims = [claim for claim in response.claims if claim.verifiable]

# %%
# Convert the claims into JSON
claims_json = response.json()

# %%
# Verify Claims 

structured_verification_llm = model.with_structured_output(VerificationList)

verification_prompt = ChatPromptTemplate.from_messages([
    ("system", "Verify each of the provided quotes. Provide your reasoning and the sources for the reasoning"),
    ("human", "{claims}")
])

verification_chain = verification_prompt | structured_verification_llm

verification_response = verification_chain.invoke({
    "claims": claims_json
})

print(verification_response)
# Out:
# verification_results=[VerificationResult(claim=Claim(number=1, description='90% of public charging points for Germany’s 2030 target remain to be built.', verifiable=True), valid=True, reasoning='Germany has set ambitious targets for electric vehicle infrastructure by 2030, which includes a significant increase in the number of public charging points. As of recent reports, a large portion of these charging points still need to be constructed to meet the 2030 goals.', sources=['https://www.reuters.com/business/autos-transportation/germany-needs-14-times-more-charging-points-meet-2030-target-2022-11-15/']), VerificationResult(claim=Claim(number=2, description='40 million electric vehicles are expected by 2030 based on emissions regulation and incentives, which is 30 million more than in 2024.', verifiable=True), valid=True, reasoning='Projections for electric vehicle growth in Europe, including Germany, suggest a significant increase due to regulatory and incentive measures. The expectation of reaching 40 million electric vehicles by 2030 aligns with these projections, considering the current growth trends and policy support.', sources=['https://www.iea.org/reports/global-ev-outlook-2022', 'https://www.euractiv.com/section/electric-cars/news/eu-electric-vehicle-sales-to-hit-30-million-by-2030/']), VerificationResult(claim=Claim(number=3, description='80% of companies with more than 20 parking spaces must install electric chargers.', verifiable=True), valid=False, reasoning='There is no widespread mandate requiring 80% of companies with more than 20 parking spaces to install electric chargers. While some countries and regions have specific regulations or incentives for installing EV chargers, this specific claim is not generally applicable.', sources=['https://www.electrive.com/2021/11/10/eu-to-require-ev-chargers-in-all-new-buildings-from-2025/']), VerificationResult(claim=Claim(number=4, description='45% of companies see complexity in billing/payments as the main challenge for e-mobility.', verifiable=True), valid=True, reasoning='Surveys and reports on e-mobility challenges often highlight billing and payment complexities as significant issues for companies. The figure of 45% is plausible based on industry reports and surveys.', sources=['https://www2.deloitte.com/content/dam/Deloitte/de/Documents/consumer-industrial-products/Deloitte-Studie-E-Mobility-2022.pdf']), VerificationResult(claim=Claim(number=6, description='Pay33 provides access to more than 650,000 EU charging points.', verifiable=True), valid=False, reasoning='There is no verifiable information available that confirms Pay33 provides access to more than 650,000 EU charging points. This claim might be exaggerated or not publicly documented.', sources=[]), VerificationResult(claim=Claim(number=7, description='Pay33 offers a white-label banking solution that opens local IBAN accounts for users in 19 EU countries.', verifiable=True), valid=False, reasoning='There is no publicly available information confirming that Pay33 offers a white-label banking solution for opening local IBAN accounts in 19 EU countries. This claim lacks verifiable sources.', sources=[]), VerificationResult(claim=Claim(number=8, description="Pay33's business model includes revenue scaling through subscriptions and transactions.", verifiable=True), valid=True, reasoning='Many companies in the fintech and e-mobility sectors use business models that include revenue from subscriptions and transactions. This is a common approach and is likely applicable to Pay33.', sources=['https://www.forbes.com/sites/forbestechcouncil/2021/06/15/how-fintech-companies-can-scale-their-business-models/']), VerificationResult(claim=Claim(number=10, description='The total addressable market for pay33 is 385 billion euros, with a serviceable obtainable market of 2 billion euros.', verifiable=True), valid=False, reasoning="There is no publicly available data or market analysis that confirms these specific figures for Pay33' ...

# %%
# Write the results into a JSON file
verification_response_json = verification_response.json()

verification_response_dictionary = json.loads(verification_response_json)

with open("verification_response.json", "w") as f:
    json.dump(verification_response_dictionary, f, indent=4)
